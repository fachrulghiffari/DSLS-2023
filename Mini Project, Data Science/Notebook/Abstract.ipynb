# %%
# Import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Cek File alert Kota Bandung
# Cek file aggregate_alerts_Kota Bandung.csv

# %%
df_alerts_kota_bandung = pd.read_csv(r'..\Data\aggregate_alerts_Kota Bandung.csv')

# %%
df_alerts_kota_bandung.sample(5)
# Out:
#             id                     time  kemendagri_kabupaten_kode  \
# 21121  6133963  2022-08-18 18:00:00.000                      32.73
# 19655  6121033  2022-08-15 13:00:00.000                      32.73
# 16735  6092776  2022-08-09 07:00:00.000                      32.73
# 19369  6116945  2022-08-14 18:00:00.000                      32.73
# 17415  6097504  2022-08-10 21:00:00.000                      32.73
#
#       kemendagri_kabupaten_nama                      street           type  \
# 21121              KOTA BANDUNG                  Jalan Aceh            JAM
# 19655              KOTA BANDUNG        Batununggal Jelita 1  WEATHERHAZARD
# 16735              KOTA BANDUNG             Terusan Jakarta            JAM
# 19369              KOTA BANDUNG                 Ciumbuleuit            JAM
# 17415              KOTA BANDUNG  N11 Flyover Kopo-Cibaduyut    ROAD_CLOSED
#
#                                    avg_location  total_records        date
# ...

# %%
df_alerts_kota_bandung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30385 entries, 0 to 30384
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         30385 non-null  int64
#  1   time                       30385 non-null  object
#  2   kemendagri_kabupaten_kode  30385 non-null  float64
#  3   kemendagri_kabupaten_nama  30385 non-null  object
#  4   street                     28496 non-null  object
#  5   type                       30385 non-null  object
#  6   avg_location               30385 non-null  object
#  7   total_records              30385 non-null  int64
#  8   date                       30385 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 2.1+ MB

# %%
df_alerts_kota_bandung.isnull().sum()
# Out:
# id                              0
# time                            0
# kemendagri_kabupaten_kode       0
# kemendagri_kabupaten_nama       0
# street                       1889
# type                            0
# avg_location                    0
# total_records                   0
# date                            0
# dtype: int64

# %%
df_alerts_kota_bandung[df_alerts_kota_bandung['avg_location'] == '[107.69066199999999, -6.958103499999996]']
# Out:
#            id                     time  kemendagri_kabupaten_kode  \
# 7     5930358  2022-07-06 00:00:00.000                      32.73
# 16    5930374  2022-07-06 02:00:00.000                      32.73
# 26    5930382  2022-07-06 03:00:00.000                      32.73
# 148   5930499  2022-07-06 10:00:00.000                      32.73
# 171   5930523  2022-07-06 11:00:00.000                      32.73
# 373   5930766  2022-07-06 18:00:00.000                      32.73
# 480   5930831  2022-07-06 20:00:00.000                      32.73
# 575   5934911  2022-07-07 08:00:00.000                      32.73
# 622   5934966  2022-07-07 11:00:00.000                      32.73
# 833   5935158  2022-07-07 17:00:00.000                      32.73
# 908   5935234  2022-07-07 19:00:00.000                      32.73
# 1033  5939754  2022-07-08 09:00:00.000                      32.73
# 1067  5939776  2022-07-08 10:00:00.000                      32.73
# ...

# %%
df_alerts_kota_bandung.head()
# Out:
#         id                     time  kemendagri_kabupaten_kode  \
# 0  5930351  2022-07-06 00:00:00.000                      32.73
# 1  5930352  2022-07-06 00:00:00.000                      32.73
# 2  5930353  2022-07-06 00:00:00.000                      32.73
# 3  5930354  2022-07-06 00:00:00.000                      32.73
# 4  5930355  2022-07-06 00:00:00.000                      32.73
#
#   kemendagri_kabupaten_nama                 street           type  \
# 0              KOTA BANDUNG    Batununggal Indah 2  WEATHERHAZARD
# 1              KOTA BANDUNG         Cibaduyut Raya    ROAD_CLOSED
# 2              KOTA BANDUNG  Gerbang Tol Gede Bage    ROAD_CLOSED
# 3              KOTA BANDUNG    Jenderal Ahmad Yani  WEATHERHAZARD
# 4              KOTA BANDUNG        KH Wahid Hasyim    ROAD_CLOSED
#
#                                 avg_location  total_records        date
# 0   [107.62634049999998, -6.962361499999998]            120  2022-07-06
# ...

# %% [markdown]
# ## Cek File Median Irregularities Kota Bandung
# Cek file aggregate_median_irregularities_Kota Bandung.csv

# %%
df_median_irregularities_kota_bandung = pd.read_csv(r'..\Data\aggregate_median_irregularities_Kota Bandung.csv')

# %%
df_median_irregularities_kota_bandung.head(5)
# Out:
#                       time  kemendagri_kabupaten_kode  \
# 0  2022-07-06 07:00:00.000                      32.73
# 1  2022-07-06 07:00:00.000                      32.73
# 2  2022-07-06 07:00:00.000                      32.73
# 3  2022-07-06 07:00:00.000                      32.73
# 4  2022-07-06 07:00:00.000                      32.73
#
#   kemendagri_kabupaten_nama                street  jam_level  median_length  \
# 0              KOTA BANDUNG     Terusan Buah Batu          4         1922.0
# 1              KOTA BANDUNG  Jenderal AH Nasution          3         1819.0
# 2              KOTA BANDUNG  Jenderal AH Nasution          4         1064.0
# 3              KOTA BANDUNG    N11 Soekarno-Hatta          4          919.0
# 4              KOTA BANDUNG     Terusan Buah Batu          3         2024.0
#
#    median_delay_seconds  median_regular_speed  total_records  cause_type  \
# 0                 657.0             15.770000             13         NaN
# ...

# %%
df_median_irregularities_kota_bandung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11281 entries, 0 to 11280
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   time                       11281 non-null  object
#  1   kemendagri_kabupaten_kode  11281 non-null  float64
#  2   kemendagri_kabupaten_nama  11281 non-null  object
#  3   street                     11279 non-null  object
#  4   jam_level                  11281 non-null  int64
#  5   median_length              11281 non-null  float64
#  6   median_delay_seconds       11281 non-null  float64
#  7   median_regular_speed       11281 non-null  float64
#  8   total_records              11281 non-null  int64
#  9   cause_type                 0 non-null      float64
#  10  median_seconds             11281 non-null  float64
#  11  median_speed               11281 non-null  float64
#  12  date                       11281 non-null  object
# ...

# %%
df_median_irregularities_kota_bandung.head()
# Out:
#                       time  kemendagri_kabupaten_kode  \
# 0  2022-07-06 07:00:00.000                      32.73
# 1  2022-07-06 07:00:00.000                      32.73
# 2  2022-07-06 07:00:00.000                      32.73
# 3  2022-07-06 07:00:00.000                      32.73
# 4  2022-07-06 07:00:00.000                      32.73
#
#   kemendagri_kabupaten_nama                street  jam_level  median_length  \
# 0              KOTA BANDUNG     Terusan Buah Batu          4         1922.0
# 1              KOTA BANDUNG  Jenderal AH Nasution          3         1819.0
# 2              KOTA BANDUNG  Jenderal AH Nasution          4         1064.0
# 3              KOTA BANDUNG    N11 Soekarno-Hatta          4          919.0
# 4              KOTA BANDUNG     Terusan Buah Batu          3         2024.0
#
#    median_delay_seconds  median_regular_speed  total_records  cause_type  \
# 0                 657.0             15.770000             13         NaN
# ...

# %% [markdown]
# ## Cek File Median Jams Kota Bandung
# Cek file aggregate_median_Jams_Kota Bandung.csv

# %%
df_median_jams_kota_bandung = pd.read_csv(r'..\Data\aggregate_median_jams_Kota Bandung_fixed.csv')

# %%
df_median_jams_kota_bandung.sample(5)
# Out:
#         Unnamed: 0                     time  kemendagri_kabupaten_kode  \
# 143358      125491  2022-08-03 15:00:00.000                      32.73
# 228404       78526  2022-08-21 13:00:00.000                      32.73
# 45966        28099  2022-07-16 09:00:00.000                      32.73
# 244439       94561  2022-08-25 06:00:00.000                      32.73
# 5605           462  2022-07-07 08:00:00.000                      32.73
#
#        kemendagri_kabupaten_nama                street  level  median_length  \
# 143358              KOTA BANDUNG             Gardujati      3          418.0
# 228404              KOTA BANDUNG               Cikutra      2          605.5
# 45966               KOTA BANDUNG              Surapati      2         1370.0
# 244439              KOTA BANDUNG              Surapati      4          937.0
# 5605                KOTA BANDUNG  Jenderal AH Nasution      3         1395.0
#
# ...

# %%
df_median_jams_kota_bandung.head()
# Out:
#    Unnamed: 0                     time  kemendagri_kabupaten_kode  \
# 0           0  2022-07-06 00:00:00.000                      32.73
# 1           1  2022-07-06 00:00:00.000                      32.73
# 2           2  2022-07-06 00:00:00.000                      32.73
# 3           3  2022-07-06 00:00:00.000                      32.73
# 4           4  2022-07-06 00:00:00.000                      32.73
#
#   kemendagri_kabupaten_nama                 street  level  median_length  \
# 0              KOTA BANDUNG    Jenderal Ahmad Yani      4          428.0
# 1              KOTA BANDUNG         Cibaduyut Raya      5           24.0
# 2              KOTA BANDUNG       Cidurian Selatan      2          531.0
# 3              KOTA BANDUNG           Dr Setiabudi      1          919.0
# 4              KOTA BANDUNG  Gerbang Tol Gede Bage      5          318.5
#
#    median_delay  median_speed_kmh  total_records        id        date  \
# ...

# %%
df_median_jams_kota_bandung = df_median_jams_kota_bandung.drop('Unnamed: 0',1)
df_median_jams_kota_bandung.head()
# Out:
# C:\Users\Fachrul Ghiffari\AppData\Local\Temp\ipykernel_9948\3632284102.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df_median_jams_kota_bandung = df_median_jams_kota_bandung.drop('Unnamed: 0',1)
#                       time  kemendagri_kabupaten_kode  \
# 0  2022-07-06 00:00:00.000                      32.73
# 1  2022-07-06 00:00:00.000                      32.73
# 2  2022-07-06 00:00:00.000                      32.73
# 3  2022-07-06 00:00:00.000                      32.73
# 4  2022-07-06 00:00:00.000                      32.73
#
#   kemendagri_kabupaten_nama                 street  level  median_length  \
# 0              KOTA BANDUNG    Jenderal Ahmad Yani      4          428.0
# 1              KOTA BANDUNG         Cibaduyut Raya      5           24.0
# 2              KOTA BANDUNG       Cidurian Selatan      2          531.0
# ...

# %%
df_median_jams_kota_bandung.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301995 entries, 0 to 301994
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   time                       301995 non-null  object
#  1   kemendagri_kabupaten_kode  301995 non-null  float64
#  2   kemendagri_kabupaten_nama  301995 non-null  object
#  3   street                     299552 non-null  object
#  4   level                      301995 non-null  int64
#  5   median_length              301995 non-null  float64
#  6   median_delay               301995 non-null  float64
#  7   median_speed_kmh           301995 non-null  float64
#  8   total_records              301995 non-null  int64
#  9   id                         301995 non-null  int64
#  10  date                       301995 non-null  object
#  11  median_level               301995 non-null  float64
#  12  geometry                   301995 non-null  object
# ...
